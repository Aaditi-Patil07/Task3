# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
ds=pd.read_csv("employee_dataset_for_eda.csv")
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# 3                      1           41954               74.4
# 4                     12          103340               82.5
# ..                   ...             ...                ...
# 195                   12           93230               67.3
# 196                    9          104055               58.3
# 197                   17           86373               62.6
# 198                    7           61480               60.7
# 199                    7          115230               75.9
#
# [200 rows x 8 columns]

# %% [markdown]
# # Categarical variable visualization

# %%
#Employee count per department

sns.countplot(data=ds,x='Department',palette='Set2')
plt.title('Employee count per Department')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15864\1892190499.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Department',palette='Set2')
# Text(0.5, 1.0, 'Employee count per Department')

# %% [markdown]
# Finance employee more than markting employee and engineering employee

# %%
#Gender Distribution

sns.countplot(data=ds,x='Gender',palette='coolwarm')
plt.title('Gender Distribution')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15864\2275039401.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Gender',palette='coolwarm')
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# Female count are greater than Male

# %%
#Employee Location Distribution

sns.countplot(data=ds,x='Location',palette='Spectral')
plt.title('Number of employee by location')
plt.xticks(rotation=45)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15864\307651785.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Location',palette='Spectral')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %%
#Age Distribution

sns.histplot(ds['Age'],bins=10,kde=True)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
#Years of Experience Distribution

sns.histplot(ds['Years_of_Experience'],bins=15,kde=True)
plt.title('Year of Experience')
# Out:
# Text(0.5, 1.0, 'Year of Experience')

# %%
#Years of Experience Distribution

sns.histplot(ds['Years_of_Experience'],bins=10,kde=True)
plt.title('Year of Experience')
# Out:
# Text(0.5, 1.0, 'Year of Experience')

# %%
#Monthly Salary Distribution

sns.boxplot(data=ds,y='Monthly_Salary',color='lightblue')
plt.title('Salary Spread')
# Out:
# Text(0.5, 1.0, 'Salary Spread')

# %%
#Average Salary by Department

sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
plt.title('Average Salary by Department')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15864\2928624001.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
# Text(0.5, 1.0, 'Average Salary by Department')

# %%
#Performance Score by Department

sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
plt.title('Performance Score by Department')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15864\2637269633.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
# Text(0.5, 1.0, 'Performance Score by Department')

# %%
#Salary Distribution by Gender

sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
plt.title('Salary by Gender')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15864\945053503.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
# Text(0.5, 1.0, 'Salary by Gender')

# %%
sns.heatmap(ds[['Age','Years_of_Experience','Monthly_Salary','Performance_Score']].corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#Salary vs Experience Scatter Plot

sns.scatterplot(data=ds,x='Years_of_Experience',y='Monthly_Salary',hue='Department')
plt.title('Salary vs. Experience by Department')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 #Salary vs Experience Scatter Plot
# ----> 3 sns.scatterplot(data=ds,x='Year_of_Experience',y='Monthly_Salary',hue='Department')
#       4 plt.title('Salary vs. Experience by Department')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Year_of_Experience` for `x`. An entry with this name does not appear in `data`.
